# %%
import cv2
import numpy as np
import threading
import socket
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

# --- Load YOLO ---
model = YOLO("model.pt")

# --- DeepSORT ---
# Explicitly specify the model for feature extraction to ensure consistency
deepsort_model = 'mobilenet'
tracker = DeepSort(max_age=10, max_iou_distance=0.4, nn_budget=100, embedder='mobilenet', n_init=3)

# --- Camera ---
ws, hs = 1280, 720
cap = cv2.VideoCapture(1)
cap.set(3, ws)
cap.set(4, hs)

# --- Socket TCP ---
HOST = '127.0.0.1'
PORT = 65432
server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
try:
    server_socket.connect((HOST, PORT))
except ConnectionRefusedError:
    print(f"Error: Could not connect to the slave at {HOST}:{PORT}. Make sure Slave.py is running.")
    exit()

def send_data(data):
    try:
        serialized_data = data.tobytes()
        server_socket.sendall(serialized_data)
    except BrokenPipeError:
        print("Error: Connection to slave lost.")
        exit()

# --- Dữ liệu chia sẻ giữa các luồng ---
detections = []
latest_frame = None
yolo_lock = threading.Lock()

# --- Hàm YOLO chạy song song ---
def run_yolo_loop():
    global detections, latest_frame
    while True:
        if latest_frame is not None:
            with yolo_lock:
                frame_copy = latest_frame.copy()
            results = model(frame_copy)
            new_detections = []
            for box in results[0].boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                confidence = box.conf[0].item()
                class_id = int(box.cls[0].item())
                if class_id == 0:  # Người
                    new_detections.append(([x1, y1, x2 - x1, y2 - y1], confidence, class_id))
            detections = new_detections

threading.Thread(target=run_yolo_loop, daemon=True).start()

# --- Mouse callback chọn người ---
cv2.namedWindow("Master")
selected_id = None

def select_object(event, x, y, flags, param):
    global selected_id
    if event == cv2.EVENT_LBUTTONDOWN:
        for track in param:
            if track.is_confirmed():
                x1, y1, x2, y2 = map(int, track.to_ltrb())
                if x1 <= x <= x2 and y1 <= y <= y2:
                    selected_id = track.track_id
                    # Gửi đặc trưng ngay khi chọn nếu có
                    # Trong Master.py, trong hàm select_object:
                    if hasattr(track, "features") and track.features:
                        feature = track.features[-1]
                        print(f"Master - Extracted feature shape: {feature.shape}") # Thêm dòng này
                        print(f"Master sending feature with shape: {feature.shape}")
                        send_data(feature)
                    print(f"🔍 Chọn đối tượng ID: {selected_id}")
                    break  # Chỉ chọn một đối tượng tại một thời điểm

cv2.setMouseCallback("Master", select_object, param=[])

# --- Vòng lặp chính ---
while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    with yolo_lock:
        latest_frame = frame.copy()

    tracks = tracker.update_tracks(detections, frame=frame)
    cv2.setMouseCallback("Master", select_object, param=tracks)

    # Hiển thị bounding box và nhận diện đối tượng
    for track in tracks:
        if track.is_confirmed():
            x1, y1, x2, y2 = map(int, track.to_ltrb())
            color = (0, 255, 0) if track.track_id == selected_id else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, f"ID {track.track_id}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    cv2.imshow("Master", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
server_socket.close()
# Out:
# 0: 480x640 1 person, 235.1ms
# Speed: 3.7ms preprocess, 235.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 284.0ms
# Speed: 4.2ms preprocess, 284.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.5ms
# Speed: 1.7ms preprocess, 211.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 244.1ms
# Speed: 2.4ms preprocess, 244.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.1ms
# Speed: 2.8ms preprocess, 251.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 245.0ms
# Speed: 2.2ms preprocess, 245.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 267.7ms
# Speed: 1.6ms preprocess, 267.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.8ms
# Speed: 2.3ms preprocess, 235.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 230.7ms
# Speed: 1.8ms preprocess, 230.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.7ms
# Speed: 2.2ms preprocess, 212.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.2ms
# Speed: 2.2ms preprocess, 199.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.9ms
# Speed: 2.0ms preprocess, 190.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.5ms
# Speed: 2.1ms preprocess, 215.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 246.2ms
# Speed: 2.5ms preprocess, 246.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.0ms
# Speed: 1.9ms preprocess, 206.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.4ms
# Speed: 1.7ms preprocess, 202.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.7ms
# Speed: 1.4ms preprocess, 204.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.3ms
# Speed: 1.7ms preprocess, 214.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.6ms
# Speed: 4.6ms preprocess, 220.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.2ms
# Speed: 1.9ms preprocess, 205.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.1ms
# Speed: 1.4ms preprocess, 200.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 217.0ms
# Speed: 1.7ms preprocess, 217.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Master - Extracted feature shape: (1280,)
# Master sending feature with shape: (1280,)
# 🔍 Chọn đối tượng ID: 1
#
# 0: 480x640 1 person, 202.6ms
# Speed: 2.1ms preprocess, 202.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.6ms
# Speed: 1.7ms preprocess, 210.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.6ms
# Speed: 1.6ms preprocess, 208.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.7ms
# Speed: 2.1ms preprocess, 201.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.7ms
# Speed: 1.9ms preprocess, 199.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.0ms
# Speed: 1.8ms preprocess, 205.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.9ms
# Speed: 1.4ms preprocess, 212.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.3ms
# Speed: 2.5ms preprocess, 195.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.7ms
# Speed: 1.8ms preprocess, 199.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.2ms
# Speed: 2.2ms preprocess, 207.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.0ms
# Speed: 1.9ms preprocess, 198.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.4ms
# Speed: 2.3ms preprocess, 220.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.8ms
# Speed: 1.7ms preprocess, 195.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.5ms
# Speed: 1.4ms preprocess, 195.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.2ms
# Speed: 1.3ms preprocess, 203.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 242.9ms
# Speed: 2.0ms preprocess, 242.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.5ms
# Speed: 2.1ms preprocess, 205.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.1ms
# Speed: 2.0ms preprocess, 191.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.7ms
# Speed: 1.4ms preprocess, 188.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.6ms
# Speed: 1.3ms preprocess, 192.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.5ms
# Speed: 3.2ms preprocess, 192.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.5ms
# Speed: 1.3ms preprocess, 192.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.0ms
# Speed: 1.5ms preprocess, 200.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.5ms
# Speed: 1.4ms preprocess, 199.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.3ms
# Speed: 1.5ms preprocess, 193.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.7ms
# Speed: 1.4ms preprocess, 186.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.9ms
# Speed: 1.7ms preprocess, 190.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.2ms
# Speed: 1.4ms preprocess, 203.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.9ms
# Speed: 1.5ms preprocess, 194.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.4ms
# Speed: 1.5ms preprocess, 205.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.8ms
# Speed: 1.9ms preprocess, 196.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.2ms
# Speed: 1.5ms preprocess, 194.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.5ms
# Speed: 2.2ms preprocess, 202.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.8ms
# Speed: 2.4ms preprocess, 189.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.0ms
# Speed: 1.6ms preprocess, 192.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.5ms
# Speed: 1.4ms preprocess, 191.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.4ms
# Speed: 1.2ms preprocess, 189.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.1ms
# Speed: 1.4ms preprocess, 197.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.3ms
# Speed: 1.9ms preprocess, 199.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.0ms
# Speed: 1.8ms preprocess, 196.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.1ms
# Speed: 1.7ms preprocess, 201.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.1ms
# Speed: 1.5ms preprocess, 186.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.1ms
# Speed: 1.6ms preprocess, 183.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.7ms
# Speed: 2.1ms preprocess, 203.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.8ms
# Speed: 1.1ms preprocess, 202.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.4ms
# Speed: 2.0ms preprocess, 194.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.7ms
# Speed: 1.3ms preprocess, 186.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.9ms
# Speed: 1.3ms preprocess, 183.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.7ms
# Speed: 1.5ms preprocess, 212.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.0ms
# Speed: 1.7ms preprocess, 198.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.4ms
# Speed: 1.4ms preprocess, 197.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.5ms
# Speed: 1.5ms preprocess, 206.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.8ms
# Speed: 1.5ms preprocess, 197.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.1ms
# Speed: 1.4ms preprocess, 198.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.3ms
# Speed: 1.7ms preprocess, 213.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.3ms
# Speed: 2.4ms preprocess, 187.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.9ms
# Speed: 1.5ms preprocess, 194.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.6ms
# Speed: 1.2ms preprocess, 195.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.8ms
# Speed: 1.4ms preprocess, 193.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.1ms
# Speed: 1.4ms preprocess, 219.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.4ms
# Speed: 1.6ms preprocess, 202.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.5ms
# Speed: 1.3ms preprocess, 197.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.5ms
# Speed: 1.3ms preprocess, 190.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.9ms
# Speed: 1.5ms preprocess, 196.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.9ms
# Speed: 1.3ms preprocess, 205.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.2ms
# Speed: 1.7ms preprocess, 199.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.5ms
# Speed: 2.0ms preprocess, 198.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.5ms
# Speed: 1.2ms preprocess, 188.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.5ms
# Speed: 1.0ms preprocess, 186.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.2ms
# Speed: 1.2ms preprocess, 195.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.9ms
# Speed: 1.4ms preprocess, 194.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.4ms
# Speed: 2.2ms preprocess, 191.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.0ms
# Speed: 1.5ms preprocess, 196.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.4ms
# Speed: 1.7ms preprocess, 193.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.7ms
# Speed: 1.7ms preprocess, 192.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.9ms
# Speed: 1.5ms preprocess, 212.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.9ms
# Speed: 1.7ms preprocess, 197.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.0ms
# Speed: 1.3ms preprocess, 189.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.5ms
# Speed: 1.3ms preprocess, 193.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.5ms
# Speed: 2.0ms preprocess, 190.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.1ms
# Speed: 1.6ms preprocess, 199.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.8ms
# Speed: 1.8ms preprocess, 200.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.7ms
# Speed: 1.4ms preprocess, 201.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.2ms
# Speed: 1.9ms preprocess, 207.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.6ms
# Speed: 1.2ms preprocess, 210.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 363.8ms
# Speed: 1.1ms preprocess, 363.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 278.2ms
# Speed: 2.3ms preprocess, 278.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 257.7ms
# Speed: 1.8ms preprocess, 257.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 234.3ms
# Speed: 3.4ms preprocess, 234.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.9ms
# Speed: 1.8ms preprocess, 241.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.4ms
# Speed: 2.8ms preprocess, 251.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.6ms
# Speed: 2.0ms preprocess, 241.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 267.5ms
# Speed: 2.1ms preprocess, 267.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 268.4ms
# Speed: 2.6ms preprocess, 268.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 262.5ms
# Speed: 1.6ms preprocess, 262.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 225.7ms
# Speed: 2.1ms preprocess, 225.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.2ms
# Speed: 1.8ms preprocess, 251.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.3ms
# Speed: 2.0ms preprocess, 251.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 259.8ms
# Speed: 2.3ms preprocess, 259.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 237.0ms
# Speed: 1.7ms preprocess, 237.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 250.7ms
# Speed: 2.5ms preprocess, 250.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 232.1ms
# Speed: 1.8ms preprocess, 232.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 238.2ms
# Speed: 2.0ms preprocess, 238.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 262.4ms
# Speed: 2.3ms preprocess, 262.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.7ms
# Speed: 2.1ms preprocess, 324.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 322.0ms
# Speed: 2.2ms preprocess, 322.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 363.7ms
# Speed: 2.7ms preprocess, 363.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 316.8ms
# Speed: 1.7ms preprocess, 316.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 308.6ms
# Speed: 2.6ms preprocess, 308.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 321.0ms
# Speed: 2.7ms preprocess, 321.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 356.8ms
# Speed: 1.6ms preprocess, 356.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 380.2ms
# Speed: 4.0ms preprocess, 380.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 353.7ms
# Speed: 2.4ms preprocess, 353.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 392.7ms
# Speed: 1.7ms preprocess, 392.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 313.2ms
# Speed: 2.2ms preprocess, 313.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.9ms
# Speed: 1.9ms preprocess, 318.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.4ms
# Speed: 1.6ms preprocess, 318.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 304.5ms
# Speed: 2.2ms preprocess, 304.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.0ms
# Speed: 3.2ms preprocess, 325.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.2ms
# Speed: 2.4ms preprocess, 324.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 314.0ms
# Speed: 2.0ms preprocess, 314.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.1ms
# Speed: 1.8ms preprocess, 312.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.1ms
# Speed: 2.5ms preprocess, 312.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.4ms
# Speed: 2.0ms preprocess, 318.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 314.8ms
# Speed: 2.2ms preprocess, 314.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.6ms
# Speed: 2.7ms preprocess, 325.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 305.2ms
# Speed: 2.5ms preprocess, 305.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 310.3ms
# Speed: 2.8ms preprocess, 310.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.3ms
# Speed: 1.9ms preprocess, 312.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.5ms
# Speed: 1.6ms preprocess, 324.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 326.1ms
# Speed: 1.6ms preprocess, 326.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 306.6ms
# Speed: 3.1ms preprocess, 306.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.0ms
# Speed: 3.0ms preprocess, 324.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 314.4ms
# Speed: 2.2ms preprocess, 314.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 322.8ms
# Speed: 1.7ms preprocess, 322.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.5ms
# Speed: 1.7ms preprocess, 324.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 316.5ms
# Speed: 3.4ms preprocess, 316.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 313.6ms
# Speed: 1.6ms preprocess, 313.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 298.4ms
# Speed: 1.9ms preprocess, 298.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.0ms
# Speed: 2.0ms preprocess, 325.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 328.9ms
# Speed: 1.9ms preprocess, 328.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.7ms
# Speed: 2.2ms preprocess, 319.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 326.1ms
# Speed: 1.9ms preprocess, 326.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 320.9ms
# Speed: 1.7ms preprocess, 320.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 339.5ms
# Speed: 42.4ms preprocess, 339.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 316.0ms
# Speed: 2.6ms preprocess, 316.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 307.7ms
# Speed: 3.1ms preprocess, 307.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 357.8ms
# Speed: 1.6ms preprocess, 357.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.1ms
# Speed: 2.7ms preprocess, 324.1ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 330.5ms
# Speed: 2.7ms preprocess, 330.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 334.7ms
# Speed: 2.9ms preprocess, 334.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 330.0ms
# Speed: 2.0ms preprocess, 330.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 347.7ms
# Speed: 2.8ms preprocess, 347.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 328.6ms
# Speed: 2.4ms preprocess, 328.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.1ms
# Speed: 2.0ms preprocess, 324.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 354.6ms
# Speed: 2.0ms preprocess, 354.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.6ms
# Speed: 2.7ms preprocess, 318.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.4ms
# Speed: 2.6ms preprocess, 324.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 336.2ms
# Speed: 2.4ms preprocess, 336.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 315.2ms
# Speed: 2.1ms preprocess, 315.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 327.4ms
# Speed: 2.7ms preprocess, 327.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 340.6ms
# Speed: 4.4ms preprocess, 340.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 305.8ms
# Speed: 2.9ms preprocess, 305.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.8ms
# Speed: 1.6ms preprocess, 324.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 320.0ms
# Speed: 1.9ms preprocess, 320.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 341.4ms
# Speed: 2.5ms preprocess, 341.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.2ms
# Speed: 2.1ms preprocess, 318.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 360.5ms
# Speed: 2.1ms preprocess, 360.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 332.7ms
# Speed: 2.0ms preprocess, 332.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 298.7ms
# Speed: 2.0ms preprocess, 298.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 313.7ms
# Speed: 1.7ms preprocess, 313.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 321.8ms
# Speed: 1.8ms preprocess, 321.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.7ms
# Speed: 1.6ms preprocess, 318.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 307.9ms
# Speed: 2.7ms preprocess, 307.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 316.6ms
# Speed: 2.9ms preprocess, 316.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.6ms
# Speed: 2.5ms preprocess, 319.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 329.8ms
# Speed: 3.0ms preprocess, 329.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 310.3ms
# Speed: 1.7ms preprocess, 310.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.6ms
# Speed: 1.9ms preprocess, 324.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 306.8ms
# Speed: 2.9ms preprocess, 306.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 310.2ms
# Speed: 1.9ms preprocess, 310.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.6ms
# Speed: 1.8ms preprocess, 325.6ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 320.6ms
# Speed: 1.9ms preprocess, 320.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 362.4ms
# Speed: 2.3ms preprocess, 362.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.5ms
# Speed: 2.3ms preprocess, 319.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.4ms
# Speed: 1.5ms preprocess, 324.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 309.2ms
# Speed: 1.9ms preprocess, 309.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 311.2ms
# Speed: 1.8ms preprocess, 311.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 328.9ms
# Speed: 2.3ms preprocess, 328.9ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 314.8ms
# Speed: 2.6ms preprocess, 314.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 296.6ms
# Speed: 3.0ms preprocess, 296.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 321.6ms
# Speed: 3.6ms preprocess, 321.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 313.6ms
# Speed: 3.1ms preprocess, 313.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 321.1ms
# Speed: 1.8ms preprocess, 321.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 311.7ms
# Speed: 1.9ms preprocess, 311.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 328.6ms
# Speed: 1.8ms preprocess, 328.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 317.0ms
# Speed: 2.3ms preprocess, 317.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 314.3ms
# Speed: 1.8ms preprocess, 314.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 347.0ms
# Speed: 3.2ms preprocess, 347.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 332.1ms
# Speed: 2.1ms preprocess, 332.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.7ms
# Speed: 3.4ms preprocess, 319.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 308.4ms
# Speed: 2.8ms preprocess, 308.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 309.6ms
# Speed: 2.5ms preprocess, 309.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 330.0ms
# Speed: 3.8ms preprocess, 330.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 300.1ms
# Speed: 2.5ms preprocess, 300.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 334.3ms
# Speed: 1.6ms preprocess, 334.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 326.6ms
# Speed: 3.6ms preprocess, 326.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.1ms
# Speed: 7.7ms preprocess, 318.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 314.7ms
# Speed: 2.0ms preprocess, 314.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 313.1ms
# Speed: 2.2ms preprocess, 313.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 314.2ms
# Speed: 2.7ms preprocess, 314.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 337.7ms
# Speed: 2.2ms preprocess, 337.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 327.6ms
# Speed: 2.9ms preprocess, 327.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.7ms
# Speed: 2.2ms preprocess, 312.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.5ms
# Speed: 2.0ms preprocess, 312.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 366.7ms
# Speed: 1.6ms preprocess, 366.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 333.6ms
# Speed: 10.8ms preprocess, 333.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 317.6ms
# Speed: 2.7ms preprocess, 317.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 314.6ms
# Speed: 2.5ms preprocess, 314.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 315.9ms
# Speed: 2.6ms preprocess, 315.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.3ms
# Speed: 1.8ms preprocess, 319.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 327.4ms
# Speed: 3.0ms preprocess, 327.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.9ms
# Speed: 3.1ms preprocess, 319.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 316.3ms
# Speed: 1.6ms preprocess, 316.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.5ms
# Speed: 2.3ms preprocess, 319.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 330.6ms
# Speed: 1.9ms preprocess, 330.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 328.3ms
# Speed: 2.4ms preprocess, 328.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 320.5ms
# Speed: 2.4ms preprocess, 320.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 324.0ms
# Speed: 2.7ms preprocess, 324.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 308.8ms
# Speed: 1.7ms preprocess, 308.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 311.6ms
# Speed: 5.6ms preprocess, 311.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 329.4ms
# Speed: 1.6ms preprocess, 329.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 317.8ms
# Speed: 2.2ms preprocess, 317.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 322.8ms
# Speed: 1.6ms preprocess, 322.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 321.2ms
# Speed: 2.6ms preprocess, 321.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 321.2ms
# Speed: 2.5ms preprocess, 321.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 310.1ms
# Speed: 1.9ms preprocess, 310.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.1ms
# Speed: 2.3ms preprocess, 312.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 332.7ms
# Speed: 2.1ms preprocess, 332.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 303.5ms
# Speed: 2.9ms preprocess, 303.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.3ms
# Speed: 2.1ms preprocess, 319.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 316.3ms
# Speed: 1.7ms preprocess, 316.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 309.5ms
# Speed: 2.4ms preprocess, 309.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.5ms
# Speed: 1.6ms preprocess, 312.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 307.2ms
# Speed: 1.8ms preprocess, 307.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.7ms
# Speed: 2.1ms preprocess, 325.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 375.7ms
# Speed: 1.8ms preprocess, 375.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 322.5ms
# Speed: 2.8ms preprocess, 322.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 321.9ms
# Speed: 2.2ms preprocess, 321.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 298.6ms
# Speed: 4.0ms preprocess, 298.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 317.9ms
# Speed: 2.5ms preprocess, 317.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.0ms
# Speed: 2.0ms preprocess, 319.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 326.1ms
# Speed: 1.9ms preprocess, 326.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.7ms
# Speed: 1.6ms preprocess, 319.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 356.3ms
# Speed: 2.0ms preprocess, 356.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 398.2ms
# Speed: 2.1ms preprocess, 398.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.6ms
# Speed: 2.4ms preprocess, 318.6ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 366.1ms
# Speed: 3.8ms preprocess, 366.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 373.8ms
# Speed: 1.8ms preprocess, 373.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 302.0ms
# Speed: 1.5ms preprocess, 302.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 330.5ms
# Speed: 1.7ms preprocess, 330.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 337.4ms
# Speed: 1.7ms preprocess, 337.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.9ms
# Speed: 1.7ms preprocess, 318.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.7ms
# Speed: 2.1ms preprocess, 312.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 337.2ms
# Speed: 2.2ms preprocess, 337.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 323.9ms
# Speed: 1.9ms preprocess, 323.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 310.8ms
# Speed: 5.2ms preprocess, 310.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 356.4ms
# Speed: 2.0ms preprocess, 356.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 458.8ms
# Speed: 2.5ms preprocess, 458.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 472.6ms
# Speed: 1.7ms preprocess, 472.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 501.6ms
# Speed: 2.2ms preprocess, 501.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 408.8ms
# Speed: 4.5ms preprocess, 408.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 424.5ms
# Speed: 2.4ms preprocess, 424.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 394.9ms
# Speed: 2.0ms preprocess, 394.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 409.4ms
# Speed: 4.1ms preprocess, 409.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 427.0ms
# Speed: 2.5ms preprocess, 427.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 352.4ms
# Speed: 2.3ms preprocess, 352.4ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 491.3ms
# Speed: 2.5ms preprocess, 491.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 455.6ms
# Speed: 2.9ms preprocess, 455.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 487.4ms
# Speed: 1.9ms preprocess, 487.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 533.9ms
# Speed: 2.0ms preprocess, 533.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 454.6ms
# Speed: 2.4ms preprocess, 454.6ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 449.2ms
# Speed: 3.0ms preprocess, 449.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 385.6ms
# Speed: 3.8ms preprocess, 385.6ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 550.6ms
# Speed: 4.0ms preprocess, 550.6ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 409.3ms
# Speed: 3.6ms preprocess, 409.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 431.6ms
# Speed: 3.5ms preprocess, 431.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 556.4ms
# Speed: 3.4ms preprocess, 556.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 425.0ms
# Speed: 2.2ms preprocess, 425.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 440.4ms
# Speed: 3.3ms preprocess, 440.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 525.1ms
# Speed: 6.2ms preprocess, 525.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 362.4ms
# Speed: 3.5ms preprocess, 362.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 339.1ms
# Speed: 4.9ms preprocess, 339.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 332.8ms
# Speed: 2.0ms preprocess, 332.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 344.0ms
# Speed: 2.6ms preprocess, 344.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 343.3ms
# Speed: 4.0ms preprocess, 343.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 295.9ms
# Speed: 1.7ms preprocess, 295.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 304.0ms
# Speed: 2.8ms preprocess, 304.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 362.6ms
# Speed: 1.7ms preprocess, 362.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 344.5ms
# Speed: 4.0ms preprocess, 344.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 333.4ms
# Speed: 2.6ms preprocess, 333.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 402.4ms
# Speed: 2.0ms preprocess, 402.4ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 356.4ms
# Speed: 2.5ms preprocess, 356.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 341.9ms
# Speed: 4.2ms preprocess, 341.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 374.7ms
# Speed: 1.6ms preprocess, 374.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 410.7ms
# Speed: 1.9ms preprocess, 410.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 356.0ms
# Speed: 2.4ms preprocess, 356.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 351.5ms
# Speed: 1.9ms preprocess, 351.5ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 326.3ms
# Speed: 3.0ms preprocess, 326.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 334.5ms
# Speed: 1.6ms preprocess, 334.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 354.2ms
# Speed: 2.3ms preprocess, 354.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 305.5ms
# Speed: 3.0ms preprocess, 305.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 346.1ms
# Speed: 4.1ms preprocess, 346.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 338.2ms
# Speed: 2.7ms preprocess, 338.2ms inference, 39.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 336.4ms
# Speed: 4.6ms preprocess, 336.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 342.8ms
# Speed: 2.3ms preprocess, 342.8ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 347.7ms
# Speed: 2.3ms preprocess, 347.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 354.9ms
# Speed: 2.1ms preprocess, 354.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 358.2ms
# Speed: 2.8ms preprocess, 358.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 375.6ms
# Speed: 2.3ms preprocess, 375.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 325.9ms
# Speed: 3.7ms preprocess, 325.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 341.9ms
# Speed: 1.9ms preprocess, 341.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 341.7ms
# Speed: 1.7ms preprocess, 341.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 478.1ms
# Speed: 4.9ms preprocess, 478.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 415.5ms
# Speed: 4.3ms preprocess, 415.5ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 434.3ms
# Speed: 4.8ms preprocess, 434.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 379.8ms
# Speed: 2.9ms preprocess, 379.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 429.0ms
# Speed: 3.6ms preprocess, 429.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 441.8ms
# Speed: 5.6ms preprocess, 441.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 391.1ms
# Speed: 3.9ms preprocess, 391.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 722.9ms
# Speed: 3.5ms preprocess, 722.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 366.3ms
# Speed: 2.7ms preprocess, 366.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 505.7ms
# Speed: 3.0ms preprocess, 505.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 386.5ms
# Speed: 3.4ms preprocess, 386.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 361.1ms
# Speed: 3.7ms preprocess, 361.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 414.5ms
# Speed: 2.8ms preprocess, 414.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 backpack, 346.7ms
# Speed: 4.4ms preprocess, 346.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 backpack, 343.3ms
# Speed: 3.8ms preprocess, 343.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)

# %%
import cv2
import os
import numpy as np
from ultralytics import YOLO
from deep_sort_realtime.deep_sort import nn_matching
from deep_sort_realtime.deepsort_tracker import DeepSort

# --- Load YOLO face model ---
model = YOLO("model.pt")  # model đã được train để detect khuôn mặt



# --- Load DeepSort Tracker ---
tracker = DeepSort(
    max_age=30,
    n_init=3,
    nms_max_overlap=1.0,
    max_cosine_distance=0.4,
    nn_budget=None,
    embedder="mobilenet",
    half=True,
    bgr=True,
    embedder_gpu=True,
)

# --- Load database đặc trưng khuôn mặt ---
def build_feature_database(data_folder='data'):
    features_db = {}
    for person_name in os.listdir(data_folder):
        person_path = os.path.join(data_folder, person_name)
        if not os.path.isdir(person_path):
            continue

        embeddings = []
        for file in os.listdir(person_path):
            if not file.lower().endswith(".jpg"):
                continue
            img_path = os.path.join(person_path, file)
            img = cv2.imread(img_path)
            if img is None:
                continue
            try:
                feature = tracker  # Sử dụng embedder để trích xuất đặc trưng
                embeddings.append(feature)
            except Exception as e:
                print(f"❌ Lỗi trích đặc trưng: {img_path} - {e}")
        if embeddings:
            avg_feature = np.mean(embeddings, axis=0)
            features_db[person_name] = avg_feature
    print(f"✅ Đã tải {len(features_db)} người trong database.")
    return features_db

# --- Tính độ tương đồng cosine ---
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

def recognize_face(feature, features_db, threshold=0.5):
    best_match, best_score = None, -1
    for name, db_feature in features_db.items():
        score = cosine_similarity(feature, db_feature)
        if score > best_score and score > threshold:
            best_match = name
            best_score = score
    return best_match, best_score

# --- Load đặc trưng khuôn mặt ---
features_db = build_feature_database("data")

# --- Mở camera ---
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)

# Lưu thông tin tên đã nhận diện cho mỗi track_id
track_id_to_name = {}

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)[0]
    detections = []

    for box in results.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = float(box.conf[0])
        cls = int(box.cls[0])
        if cls == 0:  # class 0 là khuôn mặt
            detections.append(([x1, y1, x2, y2], conf, 'face'))

    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()
        x1, y1, x2, y2 = map(int, ltrb)

        # Nếu track_id chưa có trong từ điển => nhận diện
        if track_id not in track_id_to_name:
            face_crop = frame[y1:y2, x1:x2]
            try:
                feature = tracker.embedder.get_features(face_crop)[0]  # Trích đặc trưng khuôn mặt
                name, score = recognize_face(feature, features_db, threshold=0.5)
                if name:
                    track_id_to_name[track_id] = f"{name} ({score:.2f})"
                else:
                    track_id_to_name[track_id] = "Unknown"
            except Exception as e:
                print(f"Lỗi nhận diện: {e}")
                track_id_to_name[track_id] = "Error"

        # Hiển thị thông tin
        label = track_id_to_name.get(track_id, "Processing...")
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f"ID:{track_id} {label}", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

    cv2.imshow("Face Tracking & Recognition", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import os
import numpy as np
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

# --- Hàm tiền xử lý ảnh khuôn mặt ---
def preprocess_face(face_img, target_size=(128, 128)):
    face_img = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)
    face_img = cv2.resize(face_img, target_size)
    face_img = face_img.astype(np.float32) / 255.0  # Chuẩn hóa
    return face_img

# --- Hàm tính cosine similarity ---
def cosine_similarity(a, b):
    a = a.flatten()
    b = b.flatten()
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# --- Hàm nhận diện khuôn mặt ---
def recognize_face(feature, features_db, threshold=0.6):
    best_match = ("Unknown", 0)
    for name, db_feature in features_db.items():
        similarity = cosine_similarity(feature, db_feature)
        if similarity > threshold and similarity > best_match[1]:
            best_match = (name, similarity)
    return best_match

# --- Xây dựng database đặc trưng khuôn mặt ---
def build_feature_database(model, tracker, data_folder='data'):
    features_db = {}
    
    for person_name in os.listdir(data_folder):
        person_path = os.path.join(data_folder, person_name)
        if not os.path.isdir(person_path):
            continue

        embeddings = []
        
        for file in os.listdir(person_path):
            if not file.lower().endswith((".jpg", ".jpeg", ".png")):
                continue
                
            img_path = os.path.join(person_path, file)
            img = cv2.imread(img_path)
            if img is None:
                continue
            
            # Phát hiện khuôn mặt trong ảnh
            results = model(img)[0]
            faces = []
            
            for box in results.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                conf = float(box.conf[0])
                cls = int(box.cls[0])
                if cls == 0 and conf > 0.5:  # Class 0 là khuôn mặt và confidence > 50%
                    faces.append((x1, y1, x2, y2))
            
            if not faces:
                continue  # Bỏ qua nếu không phát hiện khuôn mặt
                
            try:
                # Lấy khuôn mặt đầu tiên
                x1, y1, x2, y2 = faces[0]
                face_crop = img[y1:y2, x1:x2]
                
                # Tiền xử lý và trích xuất đặc trưng
                processed_face = preprocess_face(face_crop)
                feature = tracker.embedder.embed(processed_face)
                embeddings.append(feature)
            except Exception as e:
                print(f"❌ Lỗi xử lý ảnh {file}: {str(e)}")
                continue
        
        if embeddings:
            avg_feature = np.mean(embeddings, axis=0)
            features_db[person_name] = avg_feature
            print(f"✅ Đã thêm {person_name} vào database")
    
    print(f"\n🎉 Hoàn thành! Tổng số người trong database: {len(features_db)}")
    return features_db

# --- Hàm chính ---
def main():
    # --- Khởi tạo YOLO model ---
    model = YOLO("model.pt")  # Model phát hiện khuôn mặt
    
    # --- Khởi tạo DeepSort tracker ---
    tracker = DeepSort(
        max_age=30,
        n_init=3,
        nms_max_overlap=1.0,
        max_cosine_distance=0.4,
        nn_budget=None,
        embedder="mobilenet",
        half=True,
        bgr=True,
        embedder_gpu=True,
    )
    
    # --- Xây dựng database đặc trưng ---
    print("\n🔍 Đang xây dựng database đặc trưng khuôn mặt...")
    features_db = build_feature_database(model, tracker, "data")
    
    # --- Mở camera ---
    cap = cv2.VideoCapture(0)
    cap.set(3, 1280)  # Chiều rộng
    cap.set(4, 720)   # Chiều cao
    
    # Lưu thông tin nhận diện cho mỗi track_id
    track_id_to_name = {}
    
    print("\n🚀 Bắt đầu nhận diện khuôn mặt real-time...")
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        # Phát hiện khuôn mặt với YOLO
        results = model(frame)[0]
        detections = []
        
        for box in results.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = float(box.conf[0])
            cls = int(box.cls[0])
            if cls == 0 and conf > 0.5:  # Chỉ lấy khuôn mặt với confidence > 50%
                detections.append(([x1, y1, x2-x1, y2-y1], conf, 'face'))
        
        # Cập nhật tracker
        tracks = tracker.update_tracks(detections, frame=frame)
        
        for track in tracks:
            if not track.is_confirmed():
                continue
            
            track_id = track.track_id
            ltrb = track.to_ltrb()
            x1, y1, x2, y2 = map(int, ltrb)
            
            # Nếu track_id chưa được nhận diện
            if track_id not in track_id_to_name:
                try:
                    face_crop = frame[y1:y2, x1:x2]
                    processed_face = preprocess_face(face_crop)
                    feature = tracker.embedder.embed(processed_face)
                    name, score = recognize_face(feature, features_db)
                    track_id_to_name[track_id] = (name, score)
                    print(f"👤 Nhận diện: ID {track_id} - {name} (Độ chính xác: {score:.2f})")
                except Exception as e:
                    print(f"⚠️ Lỗi nhận diện ID {track_id}: {str(e)}")
                    track_id_to_name[track_id] = ("Error", 0)
            
            # Hiển thị thông tin
            name, score = track_id_to_name.get(track_id, ("Unknown", 0))
            color = (0, 255, 0) if name != "Unknown" else (0, 0, 255)
            
            # Vẽ bounding box và label
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.rectangle(frame, (x1, y1-35), (x1+200, y1), color, -1)
            cv2.putText(frame, f"ID:{track_id} {name}", (x1, y1-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
            
            if name != "Unknown":
                cv2.putText(frame, f"Score: {score:.2f}", (x1, y1-30),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
        
        # Hiển thị FPS
        fps = cap.get(cv2.CAP_PROP_FPS)
        cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        cv2.imshow("Face Recognition System", frame)
        
        # Thoát khi nhấn 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    # Giải phóng tài nguyên
    cap.release()
    cv2.destroyAllWindows()
    print("\n🛑 Đã dừng hệ thống nhận diện")

if __name__ == "__main__":
    main()

# %%
import cv2
import numpy as np
import threading
import socket
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import struct

# --- Load YOLO ---
model = YOLO("model.pt")

# --- DeepSORT ---
# tracker = DeepSort(max_age=50, max_iou_distance=0.4, nn_budget=100, embedder='mobilenet', n_init=3)
tracker = DeepSort(
      max_age=30,
        n_init=3,
        nms_max_overlap=1.0,
        max_cosine_distance=0.4,
        nn_budget=None,
        embedder="mobilenet",
        half=True,
        bgr=True,
        embedder_gpu=True,
)

# --- Camera ---
cap = cv2.VideoCapture(1)
cap.set(3, 1280)
cap.set(4, 720)

# --- Socket TCP ---
HOST = '192.168.1.241'
PORT = 65432
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
try:
    client_socket.connect((HOST, PORT))
except ConnectionRefusedError:
    print("❌ Không kết nối được đến Slave.")
    exit()

def send_feature_data(feature: np.ndarray):
    try:
        serialized = feature.astype(np.float32).tobytes()
        length = struct.pack(">I", len(serialized))  # Gửi độ dài 4 byte
        client_socket.sendall(length + serialized)
        print(f"📤 Gửi đặc trưng dài {len(serialized)} byte")
    except Exception as e:
        print(f"❌ Gửi thất bại: {e}")

# --- Shared ---
detections = []
latest_frame = None
selected_id = None
yolo_lock = threading.Lock()

# --- YOLO Thread ---
def yolo_thread():
    global detections, latest_frame
    while True:
        if latest_frame is not None:
            with yolo_lock:
                frame = latest_frame.copy()
            results = model(frame)
            dets = []
            for box in results[0].boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                conf = box.conf[0].item()
                cls = int(box.cls[0].item())
                if cls == 0:
                    dets.append(([x1, y1, x2 - x1, y2 - y1], conf, cls))
            detections = dets

threading.Thread(target=yolo_thread, daemon=True).start()

# --- Mouse Callback ---
def select_object(event, x, y, flags, param):
    global selected_id
    if event == cv2.EVENT_LBUTTONDOWN:
        for track in param:
            if track.is_confirmed():
                x1, y1, x2, y2 = map(int, track.to_ltrb())
                if x1 <= x <= x2 and y1 <= y <= y2:
                    selected_id = track.track_id
                    if hasattr(track, "features") and track.features:
                        feature = track.features[-1]
                        send_feature_data(feature)
                        print(f"🔍 Chọn và gửi ID: {selected_id}")
                    break

cv2.namedWindow("Master")
cv2.setMouseCallback("Master", select_object, param=[])

# --- Main Loop ---
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    with yolo_lock:
        latest_frame = frame.copy()

    tracks = tracker.update_tracks(detections, frame=frame)
    cv2.setMouseCallback("Master", select_object, param=tracks)

    for track in tracks:
        if track.is_confirmed():
            x1, y1, x2, y2 = map(int, track.to_ltrb())
            color = (0, 255, 0) if track.track_id == selected_id else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, f"ID {track.track_id}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    cv2.imshow("Master", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
client_socket.close()
